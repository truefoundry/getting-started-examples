# %%
from config.settings import settings

# %%
settings.QDRANT_API_URL

# %%
from qdrant_client import QdrantClient

qdrant_client = QdrantClient(
    url=settings.QDRANT_API_URL,
    api_key=settings.QDRANT_API_KEY
)

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(
    model=settings.EMBEDDING_MODEL,
    api_key=settings.TFY_API_KEY,
    base_url=settings.TFY_LLM_GATEWAY_BASE_URL,
)

# %%
from langchain_qdrant import QdrantVectorStore
from qdrant_client.models import VectorParams, Distance

# Create collection if it doesn't exist
qdrant_client.create_collection(
    collection_name=settings.DEFAULT_COLLECTION_NAME,
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)

qdrant_vector_store = QdrantVectorStore(
    qdrant_client, settings.DEFAULT_COLLECTION_NAME, embeddings
)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[14], line 5
#       2 from qdrant_client.models import VectorParams, Distance
#       4 # Create collection if it doesn't exist
# ----> 5 qdrant_client.create_collection(
#       6     collection_name=settings.DEFAULT_COLLECTION_NAME,
#       7     vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
#       8 )
#      10 qdrant_vector_store = QdrantVectorStore(
#      11     qdrant_client, settings.DEFAULT_COLLECTION_NAME, embeddings
#      12 )
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/qdrant_client/qdrant_client.py:2310, in QdrantClient.create_collection(self, collection_name, vectors_config, sparse_vectors_config, shard_number, sharding_method, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, strict_mode_config, **kwargs)
#    2260 """Create empty collection with given parameters
#    2261
#    2262 Args:
#    (...)
#    2306     Operation result
#    2307 """
#    2308 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 2310 return self._client.create_collection(
#    2311     collection_name=collection_name,
#    2312     vectors_config=vectors_config,
#    2313     shard_number=shard_number,
#    2314     sharding_method=sharding_method,
#    2315     replication_factor=replication_factor,
#    2316     write_consistency_factor=write_consistency_factor,
#    2317     on_disk_payload=on_disk_payload,
#    2318     hnsw_config=hnsw_config,
#    2319     optimizers_config=optimizers_config,
#    2320     wal_config=wal_config,
#    2321     quantization_config=quantization_config,
#    2322     init_from=init_from,
#    2323     timeout=timeout,
#    2324     sparse_vectors_config=sparse_vectors_config,
#    2325     strict_mode_config=strict_mode_config,
#    2326     **kwargs,
#    2327 )
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/qdrant_client/qdrant_remote.py:2810, in QdrantRemote.create_collection(self, collection_name, vectors_config, shard_number, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, sparse_vectors_config, sharding_method, strict_mode_config, **kwargs)
#    2792     init_from = GrpcToRest.convert_init_from(init_from)
#    2794 create_collection_request = models.CreateCollection(
#    2795     vectors=vectors_config,
#    2796     shard_number=shard_number,
#    (...)
#    2807     strict_mode_config=strict_mode_config,
#    2808 )
# -> 2810 result: Optional[bool] = self.http.collections_api.create_collection(
#    2811     collection_name=collection_name,
#    2812     create_collection=create_collection_request,
#    2813     timeout=timeout,
#    2814 ).result
#    2816 assert result is not None, "Create collection returned None"
#    2817 return result
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/qdrant_client/http/api/collections_api.py:294, in SyncCollectionsApi.create_collection(self, collection_name, timeout, create_collection)
#     285 def create_collection(
#     286     self,
#     287     collection_name: str,
#     288     timeout: int = None,
#     289     create_collection: m.CreateCollection = None,
#     290 ) -> m.InlineResponse200:
#     291     """
#     292     Create new collection with given parameters
#     293     """
# --> 294     return self._build_for_create_collection(
#     295         collection_name=collection_name,
#     296         timeout=timeout,
#     297         create_collection=create_collection,
#     298     )
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/qdrant_client/http/api/collections_api.py:96, in _CollectionsApi._build_for_create_collection(self, collection_name, timeout, create_collection)
#      94 if "Content-Type" not in headers:
#      95     headers["Content-Type"] = "application/json"
# ---> 96 return self.api_client.request(
#      97     type_=m.InlineResponse200,
#      98     method="PUT",
#      99     url="/collections/{collection_name}",
#     100     headers=headers if headers else None,
#     101     path_params=path_params,
#     102     params=query_params,
#     103     content=body,
#     104 )
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/qdrant_client/http/api_client.py:89, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      87     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      88 request = self._client.build_request(method, url, **kwargs)
# ---> 89 return self.send(request, type_)
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/qdrant_client/http/api_client.py:112, in ApiClient.send(self, request, type_)
#     110     except ValidationError as e:
#     111         raise ResponseHandlingException(e)
# --> 112 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 409 (Conflict)
# Raw response content:
# b'{"status":{"error":"Wrong input: Collection `document_collection` already exists!"},"time":0.019466029}'

# %%
from utils import qdrant_vector_store
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/chromadb/api/base_http_client.py:99, in BaseHTTPClient._raise_chroma_error(resp)
#      98 try:
# ---> 99     resp.raise_for_status()
#     100 except httpx.HTTPStatusError:
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '404 Not Found' for url 'https://demo-rag-sai-chroma-sai-k-ws.tfy-usea1-ctl.devtest.truefoundry.tech/api/v2/auth/identity'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/404
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/chromadb/api/client.py:101, in Client.get_user_identity(self)
#     100 try:
# --> 101     return self._server.get_user_identity()
#     102 except httpx.ConnectError:
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/chromadb/telemetry/opentelemetry/__init__.py:150, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     149 if trace_granularity < granularity:
# --> 150     return f(*args, **kwargs)
#     151 if not tracer:
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/chromadb/api/fastapi.py:182, in FastAPI.get_user_identity(self)
#     179 @trace_method("FastAPI.get_user_identity", OpenTelemetryGranularity.OPERATION)
#     180 @override
#     181 def get_user_identity(self) -> UserIdentity:
# --> 182     return UserIdentity(**self._make_request("get", "/auth/identity"))
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/chromadb/api/fastapi.py:90, in FastAPI._make_request(self, method, path, **kwargs)
#      89 response = self._session.request(method, url, **cast(Any, kwargs))
# ---> 90 BaseHTTPClient._raise_chroma_error(response)
#      91 return orjson.loads(response.text)
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/chromadb/api/base_http_client.py:104, in BaseHTTPClient._raise_chroma_error(resp)
#     103     raise Exception(f"{resp.text} (trace ID: {trace_id})")
# --> 104 raise (Exception(resp.text))
#
# Exception: {"detail":"Not Found"}
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from utils import qdrant_vector_store
#
# File ~/dev/getting-started-examples/rag_streamlit/backend/utils.py:31
#      25 qdrant_client = QdrantClient(
#      26     url=settings.QDRANT_API_URL,
#      27     api_key=settings.QDRANT_API_KEY
#      28 )
#      30 # Initialize Chroma client for vector database operations
# ---> 31 chroma_client = HttpClient(
#      32     host=settings.CHROMADB_API_URL
#      33 )
#      35 # Configure embeddings model for converting text to vectors
#      36 embeddings = OpenAIEmbeddings(
#      37     model=settings.EMBEDDING_MODEL,
#      38     api_key=settings.TFY_API_KEY,
#      39     base_url=settings.TFY_LLM_GATEWAY_BASE_URL,
#      40 )
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/chromadb/__init__.py:203, in HttpClient(host, port, ssl, headers, settings, tenant, database)
#     200 settings.chroma_server_ssl_enabled = ssl
#     201 settings.chroma_server_headers = headers
# --> 203 return ClientCreator(tenant=tenant, database=database, settings=settings)
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/chromadb/api/client.py:65, in Client.__init__(self, tenant, database, settings)
#      62 # Get the root system component we want to interact with
#      63 self._server = self._system.instance(ServerAPI)
# ---> 65 user_identity = self.get_user_identity()
#      67 maybe_tenant, maybe_database = maybe_set_tenant_and_database(
#      68     user_identity,
#      69     overwrite_singleton_tenant_database_access_from_auth=settings.chroma_overwrite_singleton_tenant_database_access_from_auth,
#      70     user_provided_tenant=tenant,
#      71     user_provided_database=database,
#      72 )
#      73 if maybe_tenant:
#
# File ~/.pyenv/versions/3.12.6/envs/rag-streamlit/lib/python3.12/site-packages/chromadb/api/client.py:110, in Client.get_user_identity(self)
#     108     raise e
#     109 except Exception as e:
# --> 110     raise ValueError(str(e))
#
# ValueError: {"detail":"Not Found"}
